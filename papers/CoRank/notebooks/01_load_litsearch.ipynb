# %%
# !pip3 install datasets
# Out:
# Looking in indexes: https://artifactory.tcsbank.ru/artifactory/api/pypi/python-all/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.3/512.3 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 109.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 51.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.2/193.2 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 35.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 97.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.0/521.0 kB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 86.2 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 31.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
# ...

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

# %%
from src.data_loading.litsearch import (
    load_litsearch_queries,
    load_litsearch_corpus,
)

# %%
queries = load_litsearch_queries()
corpus = load_litsearch_corpus(clean=True)
# Out:
# README.md: 0.00B [00:00, ?B/s]

# %%
queries
# Out:
# DatasetDict({
#     full: Dataset({
#         features: ['query_set', 'query', 'specificity', 'quality', 'corpusids'],
#         num_rows: 597
#     })
# })

# %%
corpus
# Out:
# DatasetDict({
#     full: Dataset({
#         features: ['corpusid', 'title', 'abstract', 'citations', 'full_paper'],
#         num_rows: 64183
#     })
# })

# %%
from src.data_loading.litsearch_normalize import (
    normalize_litsearch_queries,
    normalize_litsearch_corpus,
)

# %%
queries_norm = normalize_litsearch_queries(queries["full"])
corpus_norm = normalize_litsearch_corpus(corpus["full"])

# %%
queries_norm[0]
# Out:
# {'qid': 0,
#  'text': 'Are there any research papers on methods to compress large-scale language models using task-agnostic knowledge distillation techniques?',
#  'relevant_doc_ids': [202719327]}

# %%
corpus_norm[0]
# Out:
# {'doc_id': 252715594,
#  'title': 'PHENAKI: VARIABLE LENGTH VIDEO GENERATION FROM OPEN DOMAIN TEXTUAL DESCRIPTIONS',
# ...

# %%
queries_norm
# Out:
# [{'qid': 0,
#   'text': 'Are there any research papers on methods to compress large-scale language models using task-agnostic knowledge distillation techniques?',
#   'relevant_doc_ids': [202719327]},
#  {'qid': 1,
#   'text': 'Are there any resources available for translating Tunisian Arabic dialect that contain both manually translated comments by native speakers and additional data augmented through methods like segmentation at stop words level?',
#   'relevant_doc_ids': [227231792]},
#  {'qid': 2,
#   'text': 'Are there any studies that explore post-hoc techniques for hallucination detection at both the token- and sentence-level in neural sequence generation tasks?',
#   'relevant_doc_ids': [226254579, 204976362]},
#  {'qid': 3,
#   'text': 'Are there any tools or studies that have focused on building a morphological analyzer specifically for handling multiple Arabic dialects?',
#   'relevant_doc_ids': [10961392, 12160022]},
#  {'qid': 4,
# ...

# %%
from src.data_loading.litsearch_save import (
    save_litsearch_queries_jsonl,
    save_litsearch_corpus_jsonl,
)

# сохраняем
queries_path = save_litsearch_queries_jsonl(queries_norm)
corpus_path = save_litsearch_corpus_jsonl(corpus_norm)

# выводим пути для проверки
queries_path, corpus_path
# Out:
# (PosixPath('/workdir/CoRank/data/processed/litsearch/queries.jsonl'),
#  PosixPath('/workdir/CoRank/data/processed/litsearch/corpus.jsonl'))

# %%
# посмотрим первые 3 строки файла
# !head -n 3 data/processed/litsearch/queries.jsonl
# !head -n 3 data/processed/litsearch/corpus.jsonl
# Out:
# head: cannot open 'data/processed/litsearch/queries.jsonl' for reading: No such file or directory
# head: cannot open 'data/processed/litsearch/corpus.jsonl' for reading: No such file or directory
